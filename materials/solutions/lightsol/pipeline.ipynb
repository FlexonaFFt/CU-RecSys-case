# %%
# !pip install pandas polars matplotlib scikit-learn scipy
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install implicit
# Out:
# Collecting implicit
#   Downloading implicit-0.7.2.tar.gz (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 kB 3.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from implicit) (2.0.2)
# Requirement already satisfied: scipy>=0.16 in /usr/local/lib/python3.12/dist-packages (from implicit) (1.16.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from implicit) (4.67.1)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.12/dist-packages (from implicit) (3.6.0)
# Building wheels for collected packages: implicit
#   Building wheel for implicit (pyproject.toml) ... done
#   Created wheel for implicit: filename=implicit-0.7.2-cp312-cp312-linux_x86_64.whl size=10853922 sha256=2228d96c84e9cabf9a6586dab301b035719bd3d268eaf2d491d60e06684adfdf
#   Stored in directory: /root/.cache/pip/wheels/b2/00/4f/9ff8af07a0a53ac6007ea5d739da19cfe147a2df542b6899f8
# Successfully built implicit
# Installing collected packages: implicit
# Successfully installed implicit-0.7.2

# %%
# !pip install git+https://github.com/daviddavo/lightfm
# Out:
# Collecting git+https://github.com/daviddavo/lightfm
#   Cloning https://github.com/daviddavo/lightfm to /tmp/pip-req-build-swk0b933
#   Running command git clone --filter=blob:none --quiet https://github.com/daviddavo/lightfm /tmp/pip-req-build-swk0b933
#   Resolved https://github.com/daviddavo/lightfm to commit f0eb500ead54ab65eb8e1b3890337a7223a35114
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from lightfm==1.17) (2.0.2)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from lightfm==1.17) (1.16.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from lightfm==1.17) (2.32.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from lightfm==1.17) (1.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->lightfm==1.17) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->lightfm==1.17) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->lightfm==1.17) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->lightfm==1.17) (2025.8.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->lightfm==1.17) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->lightfm==1.17) (3.6.0)
# Building wheels for collected packages: lightfm
#   Building wheel for lightfm (setup.py) ... done
#   Created wheel for lightfm: filename=lightfm-1.17-cp312-cp312-linux_x86_64.whl size=1099142 sha256=c333c433db7845321613a65d8c4f1d4da1c7105afcf6be853503614dbc6917e3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s81gsluo/wheels/fd/89/93/70c1e5f378ee5043de89387ee3ef6852ff39e3b9eb44ecc1a3
# Successfully built lightfm
# Installing collected packages: lightfm
# Successfully installed lightfm-1.17

# %%
import pandas as pd
import polars as pl
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.sparse import csr_matrix
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import normalize
from implicit.nearest_neighbours import ItemItemRecommender
from lightfm import LightFM
from lightfm.data import Dataset
from collections import Counter
import pickle
# Out:
# /usr/local/lib/python3.12/dist-packages/implicit/gpu/__init__.py:13: UserWarning: CUDA extension is built, but disabling GPU support because of 'Cuda Error: CUDA driver version is insufficient for CUDA runtime version (/tmp/pip-install-5z00sbcq/implicit_31f86adddc584d72b1acf0a0ddef892f/./implicit/gpu/utils.h:71)'
#   warnings.warn(

# %% [markdown]
# ## Загрузка данных

# %%
data_folder = "data/"
train = pl.read_parquet(data_folder + "train.pq")
test_exploded = pl.read_parquet(data_folder + "test.pq")
test = test_exploded.group_by("user_id", maintain_order=True).agg(pl.col("item_id"))
books = pl.read_parquet(data_folder + "books.pq")

print("Train:", train.shape)
display(train.head(5))
print("Test:", test.shape)
display(test.head(5))
print("Books:", books.shape)
display(books.head(5))
# Out:
# Train: (11971437, 5)
# shape: (5, 5)
# ┌─────────────────────────────────┬─────────┬─────────┬────────┬─────────────────────┐
# │ user_id                         ┆ item_id ┆ is_read ┆ rating ┆ date_added          │
# │ ---                             ┆ ---     ┆ ---     ┆ ---    ┆ ---                 │
# │ str                             ┆ i64     ┆ bool    ┆ i64    ┆ datetime[μs]        │
# ╞═════════════════════════════════╪═════════╪═════════╪════════╪═════════════════════╡
# │ 90998a29029ecb1fbeedaff2b71752… ┆ 8473    ┆ false   ┆ 0      ┆ 2014-05-15 12:51:13 │
# │ 90998a29029ecb1fbeedaff2b71752… ┆ 20060   ┆ false   ┆ 0      ┆ 2014-05-15 12:51:14 │
# │ 90998a29029ecb1fbeedaff2b71752… ┆ 8354    ┆ false   ┆ 0      ┆ 2014-05-15 12:51:17 │
# │ 90998a29029ecb1fbeedaff2b71752… ┆ 11575   ┆ false   ┆ 0      ┆ 2014-05-15 12:51:19 │
# │ 90998a29029ecb1fbeedaff2b71752… ┆ 11861   ┆ false   ┆ 0      ┆ 2014-05-15 12:51:20 │
# └─────────────────────────────────┴─────────┴─────────┴────────┴─────────────────────┘
# Test: (185828, 2)
# shape: (5, 2)
# ┌─────────────────────────────────┬───────────────────────┐
# │ user_id                         ┆ item_id               │
# │ ---                             ┆ ---                   │
# │ str                             ┆ list[i64]             │
# ╞═════════════════════════════════╪═══════════════════════╡
# │ 00000377eea48021d3002730d56aca… ┆ [13252]               │
# │ 00009ab2ed8cbfceda5a59da409663… ┆ [2328]                │
# │ 00009e46d18f223a82b22da38586b6… ┆ [28636, 30197]        │
# │ 0001085188e302fc6b2568de45a5f5… ┆ [2159, 2969, … 33630] │
# │ 00014c578111090720e20f5705eba0… ┆ [45, 3513, … 33273]   │
# └─────────────────────────────────┴───────────────────────┘
# Books: (34322, 8)
# shape: (5, 8)
# ┌─────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────────┬───────────┐
# │ item_id ┆ series     ┆ tags       ┆ title      ┆ descriptio ┆ url        ┆ image_url ┆ authors   │
# │ ---     ┆ ---        ┆ ---        ┆ ---        ┆ n          ┆ ---        ┆ ---       ┆ ---       │
# │ i64     ┆ list[str]  ┆ list[str]  ┆ str        ┆ ---        ┆ str        ┆ str       ┆ list[stru │
# │         ┆            ┆            ┆            ┆ str        ┆            ┆           ┆ ct[2]]    │
# ╞═════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╡
# │ 0       ┆ [null]     ┆ ["e-book", ┆ Hallie     ┆ There are  ┆ https://ww ┆ https://i ┆ [{"187949 │
# │         ┆            ┆ "young-adu ┆ Hath No    ┆ two sides  ┆ w.goodread ┆ mages.gr- ┆ 4",""}]   │
# │         ┆            ┆ lt", … "y… ┆ Fury . . . ┆ to every   ┆ s.com/book ┆ assets.co ┆           │
# │         ┆            ┆            ┆            ┆ s…         ┆ …          ┆ m/b…      ┆           │
# │ 1       ┆ ["149079"] ┆ ["primary" ┆ Hide and   ┆ The girls  ┆ https://ww ┆ https://s ┆ [{"21740" │
# │         ┆            ┆ , "melissa ┆ Shriek:    ┆ go on an   ┆ w.goodread ┆ .gr-asset ┆ ,""}]     │
# │         ┆            ┆ -j--morgan ┆ Super      ┆ overnight  ┆ s.com/book ┆ s.com/ass ┆           │
# │         ┆            ┆ …          ┆ Special…   ┆ a…         ┆ …          ┆ ets…      ┆           │
# │ 2       ┆ [null]     ┆ ["friendsh ┆ Dear Mom,  ┆ Samantha   ┆ https://ww ┆ https://s ┆ [{"18946" │
# │         ┆            ┆ ip", "midd ┆ You're     ┆ Slayton    ┆ w.goodread ┆ .gr-asset ┆ ,""}]     │
# │         ┆            ┆ le-reader" ┆ Ruining My ┆ worries    ┆ s.com/book ┆ s.com/ass ┆           │
# │         ┆            ┆ …          ┆ Li…        ┆ about…     ┆ …          ┆ ets…      ┆           │
# │ 3       ┆ ["151088"] ┆ ["summer-2 ┆ Bratfest   ┆ Massie     ┆ https://ww ┆ https://i ┆ [{"4605", │
# │         ┆            ┆ 017", "bul ┆ at         ┆ Block: The ┆ w.goodread ┆ mages.gr- ┆ ""}]      │
# │         ┆            ┆ lying", …  ┆ Tiffany's  ┆ Briarwood  ┆ s.com/book ┆ assets.co ┆           │
# │         ┆            ┆ …          ┆ (Clique …  ┆ bo…        ┆ …          ┆ m/b…      ┆           │
# │ 4       ┆ ["812067"] ┆ ["rosemary ┆ Questions  ┆ When Sammi ┆ https://ww ┆ https://i ┆ [{"792676 │
# │         ┆            ┆ -vernon",  ┆ of Love    ┆ Edwards is ┆ w.goodread ┆ mages.gr- ┆ ",""}]    │
# │         ┆            ┆ "young-adu ┆ (Sweet     ┆ chosen t…  ┆ s.com/book ┆ assets.co ┆           │
# │         ┆            ┆ …          ┆ Dream…     ┆            ┆ …          ┆ m/b…      ┆           │
# └─────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────────┴───────────┘

# %% [markdown]
# ## EDA

# %%
print("Train stats:")
print(f"Unique users: {train['user_id'].n_unique()}")
print(f"Unique items: {train['item_id'].n_unique()}")
print(f"Interactions: {train.shape[0]}")
print(f"Avg interactions per user: {train.shape[0] / train['user_id'].n_unique():.2f}")
print(f"Avg interactions per item: {train.shape[0] / train['item_id'].n_unique():.2f}")

cold_items = set(test_exploded["item_id"].to_list()) - set(train["item_id"].to_list())
print(f"Cold items: {len(cold_items)}")

test_exploded = test_exploded.with_columns(pl.col("item_id").is_in(list(cold_items)).alias("is_cold"))

rating_counts = train.select(pl.col("rating").value_counts()).unnest("rating")
print("Rating distribution:")
display(rating_counts)

is_read_counts = train.select(pl.col("is_read").value_counts()).unnest("is_read")
print("is_read distribution:")
display(is_read_counts)

plt.bar(rating_counts["rating"], rating_counts["count"])
plt.title("Ratings")
plt.show()

all_tags = [tag for tags in books["tags"].to_list() if tags for tag in tags]
top_tags = Counter(all_tags).most_common(10)
print("Top tags:", top_tags)

all_authors = [a["author_id"] for authors in books["authors"].to_list() if authors for a in authors]
top_authors = Counter(all_authors).most_common(10)
print("Top authors:", top_authors)

user_interactions = train.group_by("user_id").agg(pl.len().alias("interactions")).sort("interactions", descending=True)
plt.hist(user_interactions["interactions"], bins=50, log=True)
plt.title("User interactions (log)")
plt.show()

item_interactions = train.group_by("item_id").agg(pl.len().alias("interactions")).sort("interactions", descending=True)
plt.hist(item_interactions["interactions"], bins=50, log=True)
plt.title("Item interactions (log)")
plt.show()
# Out:
# Train stats:
# Unique users: 349719
# Unique items: 31300
# Interactions: 11971437
# Avg interactions per user: 34.23
# Avg interactions per item: 382.47
# Cold items: 1775
# Rating distribution:
# shape: (6, 2)
# ┌────────┬─────────┐
# │ rating ┆ count   │
# │ ---    ┆ ---     │
# │ i64    ┆ u32     │
# ╞════════╪═════════╡
# │ 3      ┆ 906917  │
# │ 0      ┆ 7649845 │
# │ 1      ┆ 88344   │
# │ 2      ┆ 257190  │
# │ 5      ┆ 1551182 │
# │ 4      ┆ 1517959 │
# └────────┴─────────┘
# is_read distribution:
# shape: (2, 2)
# ┌─────────┬─────────┐
# │ is_read ┆ count   │
# │ ---     ┆ ---     │
# │ bool    ┆ u32     │
# ╞═════════╪═════════╡
# │ false   ┆ 7279978 │
# │ true    ┆ 4691459 │
# └─────────┴─────────┘
# Top tags: [('to-read', 34125), ('young-adult', 33110), ('currently-reading', 29492), ('ya', 27595), ('fiction', 24100), ('favorites', 22233), ('books-i-own', 21406), ('owned', 20581), ('romance', 19068), ('kindle', 17116)]
# Top authors: [('2423', 426), ('13730', 208), ('169001', 166), ('50873', 124), ('11654', 121), ('5816', 115), ('3780', 89), ('233309', 85), ('9059', 84), ('19954', 82)]

# %% [markdown]
# ## Метрики

# %%
from sklearn.metrics import ndcg_score

def recall_at_k(recommended: list, relevant: list, k: int) -> float:
    return len(set(recommended[:k]) & set(relevant)) / len(relevant) if relevant else 0

def ndcg_at_k(recommended: list, relevant: list, k: int) -> float:
    ideal = sorted([1 if i in relevant else 0 for i in recommended], reverse=True)
    scores = np.array([[1 if i in relevant else 0 for i in recommended]])
    ideal_scores = np.array([ideal])
    return ndcg_score(ideal_scores, scores, k=k) if relevant else 0

def coverage(recommended_all: pl.DataFrame, total_items: int) -> float:
    unique_recs = recommended_all["recs"].explode().unique().len()
    return unique_recs / total_items

def cold_recall_at_k(test_df: pl.DataFrame, recs_df: pl.DataFrame, k: int) -> float:
    cold_test = test_df.filter(pl.col("is_cold"))
    if cold_test.shape[0] == 0:
        return 0
    cold_users = cold_test["user_id"].unique()
    cold_recs = recs_df.filter(pl.col("user_id").is_in(cold_users)).select(pl.col("recs").list.head(k))
    cold_relevant = cold_test.group_by("user_id").agg(pl.col("item_id").alias("relevant"))
    recalls = []
    for user in cold_users:
        rec = cold_recs.filter(pl.col("user_id") == user)["recs"].to_list()[0] or []
        rel = cold_relevant.filter(pl.col("user_id") == user)["relevant"].to_list()[0]
        recalls.append(recall_at_k(rec, rel, k))
    return np.mean(recalls) if recalls else 0

def evaluate_model(recs_df: pl.DataFrame, test_df: pl.DataFrame, model_name: str, total_items: int):
    metrics = {"Model": model_name}
    all_recall = []
    all_ndcg = []
    for row in test_df.iter_rows(named=True):
        recs = recs_df.filter(pl.col("user_id") == row["user_id"])["recs"].to_list()[0] or []
        rel = row["item_id"]
        all_recall.append(recall_at_k(recs, rel, 10))
        all_ndcg.append(ndcg_at_k(recs, rel, 10))
    metrics["Recall@10"] = np.mean(all_recall)
    metrics["NDCG@10"] = np.mean(all_ndcg)
    metrics["Coverage"] = coverage(recs_df, total_items)
    metrics["ColdRecall@10"] = cold_recall_at_k(test_exploded, recs_df, 10)
    return metrics

# %% [markdown]
# ## Popular

# %%
total_items = books["item_id"].n_unique()
popular_items = train.group_by("item_id").agg(pl.len().alias("pop")).sort("pop", descending=True)["item_id"].head(100).to_list()
recs_popular = [popular_items[:10] for _ in range(test.shape[0])]
test = test.with_columns(pl.Series("popular_recs", recs_popular))
pickle.dump(popular_items, open("popular_model.pkl", "wb"))

# %% [markdown]
# ## ItemKNN (warm)

# %%
# ItemKNN (Warm)
from scipy.sparse import csr_matrix
from implicit.nearest_neighbours import ItemItemRecommender

# Создаём маппинги для пользователей и айтемов
user_ids = train["user_id"].unique().to_list()
item_ids = train["item_id"].unique().to_list()
user_map = {uid: i for i, uid in enumerate(user_ids)}
item_map = {iid: i for i, iid in enumerate(item_ids)}

# Создаём разреженную матрицу user-item
# Приводим data к float64, а row/col к int32 для совместимости с implicit
data = (train["rating"].to_numpy() + 1).astype(np.float64)  # Веса в float64
row = train["user_id"].replace(user_map).to_numpy().astype(np.int32)  # Индексы в int32
col = train["item_id"].replace(item_map).to_numpy().astype(np.int32)  # Индексы в int32
sparse = csr_matrix((data, (row, col)), shape=(len(user_ids), len(item_ids)))

# Обучаем ItemKNN
model_knn = ItemItemRecommender(K=10, num_threads=4)  # num_threads для ускорения
model_knn.fit(sparse)  # Передаём user-item матрицу напрямую

# Генерируем рекомендации
recs_knn = []
for uid in tqdm(test["user_id"], desc="ItemKNN predictions"):
    u_idx = user_map.get(uid, -1)
    if u_idx == -1:
        recs_knn.append(popular_items[:10])  # Fallback на популярные
    else:
        recs, _ = model_knn.recommend(u_idx, sparse[u_idx], N=10, filter_already_liked_items=True)
        recs_knn.append([item_ids[r] for r in recs if r < len(item_ids)] or popular_items[:10])
test = test.with_columns(pl.Series("knn_recs", recs_knn))

# Сохраняем модель
with open("knn_model.pkl", "wb") as f:
    pickle.dump({"model": model_knn, "user_map": user_map, "item_map": item_map, "item_ids": item_ids}, f)
# Out:
#   0%|          | 0/31300 [00:00<?, ?it/s]
# ItemKNN predictions: 100%|██████████| 185828/185828 [00:19<00:00, 9641.04it/s]

# %% [markdown]
# ## LightFM (Cold & Warm)

# %%
# LightFM (Cold & Warm) с разделением на части
from lightfm import LightFM
from lightfm.data import Dataset
from sklearn.feature_extraction.text import CountVectorizer
from scipy.sparse import csr_matrix

# Определяем все айтемы (из train и test)
item_ids = train["item_id"].unique().to_list()
cold_items = list(set(test_exploded["item_id"].to_list()) - set(item_ids))
all_items = list(set(item_ids) | set(cold_items))
user_ids = train["user_id"].unique().to_list()

# Инициализируем dataset
dataset = Dataset()
dataset.fit(users=user_ids, items=all_items)

# Векторизация тегов только для айтемов из all_items
tag_vectorizer = CountVectorizer(max_features=1000)  # Ограничиваем число тегов для экономии памяти
books_filtered = books.filter(pl.col("item_id").is_in(all_items))
tag_matrix = tag_vectorizer.fit_transform(books_filtered["tags"].list.join(" ").to_list())

# Создаём item_features только для отфильтрованных айтемов
item_features = dataset.build_item_features(
    (iid, tag_vectorizer.transform([tags]).toarray()[0])
    for iid, tags in books_filtered.select("item_id", pl.col("tags").list.join(" ")).iter_rows()
)

# Разделяем train на батчи по пользователям
batch_size = 5000  # Количество пользователей в одном батче (настройте под вашу RAM)
user_batches = [user_ids[i:i + batch_size] for i in range(0, len(user_ids), batch_size)]

# Обучаем LightFM с прогресс-баром по батчам
model_lfm = LightFM(loss='warp', no_components=32, random_state=42)  # Уменьшено no_components для экономии памяти
num_epochs = 10  # Уменьшено число эпох для скорости
for batch_idx, batch_users in enumerate(tqdm(user_batches, desc="LightFM training batches")):
    # Фильтруем train для текущего батча пользователей
    batch_train = train.filter(pl.col("user_id").is_in(batch_users))

    # Создаём матрицу взаимодействий для батча
    batch_interactions = dataset.build_interactions(
        (u, i, r + 1) for u, i, r in batch_train.select("user_id", "item_id", "rating").iter_rows()
    )[0]  # Берем только interactions (не weights)

    # Обучаем на батче
    for epoch in tqdm(range(num_epochs), desc=f"LightFM batch {batch_idx + 1} epochs", leave=False):
        model_lfm.fit_partial(batch_interactions, item_features=item_features, epochs=1)

# Сохраняем модель
with open("lfm_model.pkl", "wb") as f:
    pickle.dump({"model": model_lfm, "dataset": dataset, "all_items": all_items, "tag_vectorizer": tag_vectorizer}, f)
# Out:
# LightFM training batches:   0%|          | 0/70 [00:00<?, ?it/s]
# LightFM batch 1 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 1 epochs:  10%|█         | 1/10 [00:02<00:21,  2.42s/it]
# LightFM batch 1 epochs:  20%|██        | 2/10 [00:04<00:17,  2.17s/it]
# LightFM batch 1 epochs:  30%|███       | 3/10 [00:06<00:13,  1.96s/it]
# LightFM batch 1 epochs:  40%|████      | 4/10 [00:07<00:11,  1.87s/it]
# LightFM batch 1 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.83s/it]
# LightFM batch 1 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.80s/it]
# LightFM batch 1 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.78s/it]
# LightFM batch 1 epochs:  80%|████████  | 8/10 [00:15<00:04,  2.05s/it]
# LightFM batch 1 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.96s/it]
# LightFM batch 1 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.91s/it]
# LightFM training batches:   1%|▏         | 1/70 [00:19<22:49, 19.85s/it]
# LightFM batch 2 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 2 epochs:  10%|█         | 1/10 [00:01<00:15,  1.74s/it]
# LightFM batch 2 epochs:  20%|██        | 2/10 [00:03<00:14,  1.78s/it]
# LightFM batch 2 epochs:  30%|███       | 3/10 [00:05<00:12,  1.80s/it]
# LightFM batch 2 epochs:  40%|████      | 4/10 [00:08<00:12,  2.15s/it]
# LightFM batch 2 epochs:  50%|█████     | 5/10 [00:09<00:10,  2.04s/it]
# LightFM batch 2 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.97s/it]
# LightFM batch 2 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.93s/it]
# LightFM batch 2 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.91s/it]
# LightFM batch 2 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.88s/it]
# LightFM batch 2 epochs: 100%|██████████| 10/10 [00:19<00:00,  2.09s/it]
# LightFM training batches:   3%|▎         | 2/70 [00:40<22:52, 20.18s/it]
# LightFM batch 3 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 3 epochs:  10%|█         | 1/10 [00:01<00:15,  1.71s/it]
# LightFM batch 3 epochs:  20%|██        | 2/10 [00:03<00:13,  1.74s/it]
# LightFM batch 3 epochs:  30%|███       | 3/10 [00:05<00:12,  1.76s/it]
# LightFM batch 3 epochs:  40%|████      | 4/10 [00:07<00:10,  1.77s/it]
# LightFM batch 3 epochs:  50%|█████     | 5/10 [00:08<00:08,  1.78s/it]
# LightFM batch 3 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.95s/it]
# LightFM batch 3 epochs:  70%|███████   | 7/10 [00:13<00:06,  2.02s/it]
# LightFM batch 3 epochs:  80%|████████  | 8/10 [00:16<00:04,  2.36s/it]
# LightFM batch 3 epochs:  90%|█████████ | 9/10 [00:18<00:02,  2.44s/it]
# LightFM batch 3 epochs: 100%|██████████| 10/10 [00:20<00:00,  2.24s/it]
# LightFM training batches:   4%|▍         | 3/70 [01:01<23:17, 20.86s/it]
# LightFM batch 4 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 4 epochs:  10%|█         | 1/10 [00:02<00:19,  2.22s/it]
# LightFM batch 4 epochs:  20%|██        | 2/10 [00:05<00:24,  3.01s/it]
# LightFM batch 4 epochs:  30%|███       | 3/10 [00:08<00:21,  3.03s/it]
# LightFM batch 4 epochs:  40%|████      | 4/10 [00:11<00:17,  2.85s/it]
# LightFM batch 4 epochs:  50%|█████     | 5/10 [00:13<00:12,  2.46s/it]
# LightFM batch 4 epochs:  60%|██████    | 6/10 [00:15<00:10,  2.52s/it]
# LightFM batch 4 epochs:  70%|███████   | 7/10 [00:18<00:08,  2.67s/it]
# LightFM batch 4 epochs:  80%|████████  | 8/10 [00:21<00:05,  2.78s/it]
# LightFM batch 4 epochs:  90%|█████████ | 9/10 [00:24<00:02,  2.67s/it]
# LightFM batch 4 epochs: 100%|██████████| 10/10 [00:26<00:00,  2.49s/it]
# LightFM training batches:   6%|▌         | 4/70 [01:28<25:34, 23.24s/it]
# LightFM batch 5 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 5 epochs:  10%|█         | 1/10 [00:02<00:18,  2.00s/it]
# LightFM batch 5 epochs:  20%|██        | 2/10 [00:03<00:15,  1.88s/it]
# LightFM batch 5 epochs:  30%|███       | 3/10 [00:05<00:13,  1.86s/it]
# LightFM batch 5 epochs:  40%|████      | 4/10 [00:07<00:11,  1.85s/it]
# LightFM batch 5 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.85s/it]
# LightFM batch 5 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.96s/it]
# LightFM batch 5 epochs:  70%|███████   | 7/10 [00:13<00:06,  2.11s/it]
# LightFM batch 5 epochs:  80%|████████  | 8/10 [00:15<00:04,  2.02s/it]
# LightFM batch 5 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.97s/it]
# LightFM batch 5 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.94s/it]
# LightFM training batches:   7%|▋         | 5/70 [01:49<24:04, 22.23s/it]
# LightFM batch 6 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 6 epochs:  10%|█         | 1/10 [00:01<00:14,  1.66s/it]
# LightFM batch 6 epochs:  20%|██        | 2/10 [00:03<00:14,  1.81s/it]
# LightFM batch 6 epochs:  30%|███       | 3/10 [00:05<00:14,  2.07s/it]
# LightFM batch 6 epochs:  40%|████      | 4/10 [00:07<00:11,  1.94s/it]
# LightFM batch 6 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.87s/it]
# LightFM batch 6 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.83s/it]
# LightFM batch 6 epochs:  70%|███████   | 7/10 [00:12<00:05,  1.81s/it]
# LightFM batch 6 epochs:  80%|████████  | 8/10 [00:14<00:03,  1.79s/it]
# LightFM batch 6 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.98s/it]
# LightFM batch 6 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.98s/it]
# LightFM training batches:   9%|▊         | 6/70 [02:08<22:46, 21.35s/it]
# LightFM batch 7 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 7 epochs:  10%|█         | 1/10 [00:01<00:15,  1.72s/it]
# LightFM batch 7 epochs:  20%|██        | 2/10 [00:03<00:13,  1.75s/it]
# LightFM batch 7 epochs:  30%|███       | 3/10 [00:05<00:12,  1.75s/it]
# LightFM batch 7 epochs:  40%|████      | 4/10 [00:07<00:10,  1.76s/it]
# LightFM batch 7 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.92s/it]
# LightFM batch 7 epochs:  60%|██████    | 6/10 [00:11<00:08,  2.01s/it]
# LightFM batch 7 epochs:  70%|███████   | 7/10 [00:13<00:06,  2.02s/it]
# LightFM batch 7 epochs:  80%|████████  | 8/10 [00:16<00:04,  2.36s/it]
# LightFM batch 7 epochs:  90%|█████████ | 9/10 [00:19<00:02,  2.41s/it]
# LightFM batch 7 epochs: 100%|██████████| 10/10 [00:24<00:00,  3.25s/it]
# LightFM training batches:  10%|█         | 7/70 [02:33<23:35, 22.47s/it]
# LightFM batch 8 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 8 epochs:  10%|█         | 1/10 [00:02<00:19,  2.16s/it]
# LightFM batch 8 epochs:  20%|██        | 2/10 [00:05<00:21,  2.68s/it]
# LightFM batch 8 epochs:  30%|███       | 3/10 [00:07<00:19,  2.72s/it]
# LightFM batch 8 epochs:  40%|████      | 4/10 [00:10<00:16,  2.69s/it]
# LightFM batch 8 epochs:  50%|█████     | 5/10 [00:12<00:11,  2.36s/it]
# LightFM batch 8 epochs:  60%|██████    | 6/10 [00:14<00:08,  2.16s/it]
# LightFM batch 8 epochs:  70%|███████   | 7/10 [00:15<00:06,  2.03s/it]
# LightFM batch 8 epochs:  80%|████████  | 8/10 [00:17<00:03,  1.95s/it]
# LightFM batch 8 epochs:  90%|█████████ | 9/10 [00:19<00:01,  1.90s/it]
# LightFM batch 8 epochs: 100%|██████████| 10/10 [00:21<00:00,  2.03s/it]
# LightFM training batches:  11%|█▏        | 8/70 [02:56<23:22, 22.61s/it]
# LightFM batch 9 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 9 epochs:  10%|█         | 1/10 [00:02<00:23,  2.59s/it]
# LightFM batch 9 epochs:  20%|██        | 2/10 [00:04<00:18,  2.29s/it]
# LightFM batch 9 epochs:  30%|███       | 3/10 [00:06<00:14,  2.05s/it]
# LightFM batch 9 epochs:  40%|████      | 4/10 [00:08<00:11,  1.95s/it]
# LightFM batch 9 epochs:  50%|█████     | 5/10 [00:10<00:09,  1.94s/it]
# LightFM batch 9 epochs:  60%|██████    | 6/10 [00:12<00:08,  2.15s/it]
# LightFM batch 9 epochs:  70%|███████   | 7/10 [00:14<00:06,  2.03s/it]
# LightFM batch 9 epochs:  80%|████████  | 8/10 [00:16<00:03,  1.96s/it]
# LightFM batch 9 epochs:  90%|█████████ | 9/10 [00:18<00:01,  1.91s/it]
# LightFM batch 9 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.88s/it]
# LightFM training batches:  13%|█▎        | 9/70 [03:18<22:37, 22.25s/it]
# LightFM batch 10 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 10 epochs:  10%|█         | 1/10 [00:01<00:15,  1.72s/it]
# LightFM batch 10 epochs:  20%|██        | 2/10 [00:04<00:17,  2.22s/it]
# LightFM batch 10 epochs:  30%|███       | 3/10 [00:06<00:14,  2.01s/it]
# LightFM batch 10 epochs:  40%|████      | 4/10 [00:07<00:11,  1.93s/it]
# LightFM batch 10 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.88s/it]
# LightFM batch 10 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.85s/it]
# LightFM batch 10 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.83s/it]
# LightFM batch 10 epochs:  80%|████████  | 8/10 [00:15<00:04,  2.01s/it]
# LightFM batch 10 epochs:  90%|█████████ | 9/10 [00:17<00:02,  2.03s/it]
# LightFM batch 10 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.95s/it]
# LightFM training batches:  14%|█▍        | 10/70 [03:38<21:34, 21.57s/it]
# LightFM batch 11 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 11 epochs:  10%|█         | 1/10 [00:01<00:16,  1.78s/it]
# LightFM batch 11 epochs:  20%|██        | 2/10 [00:03<00:14,  1.83s/it]
# LightFM batch 11 epochs:  30%|███       | 3/10 [00:05<00:12,  1.84s/it]
# LightFM batch 11 epochs:  40%|████      | 4/10 [00:08<00:12,  2.12s/it]
# LightFM batch 11 epochs:  50%|█████     | 5/10 [00:10<00:10,  2.10s/it]
# LightFM batch 11 epochs:  60%|██████    | 6/10 [00:11<00:08,  2.02s/it]
# LightFM batch 11 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.97s/it]
# LightFM batch 11 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.94s/it]
# LightFM batch 11 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.93s/it]
# LightFM batch 11 epochs: 100%|██████████| 10/10 [00:20<00:00,  2.09s/it]
# LightFM training batches:  16%|█▌        | 11/70 [03:58<20:56, 21.30s/it]
# LightFM batch 12 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 12 epochs:  10%|█         | 1/10 [00:01<00:15,  1.76s/it]
# LightFM batch 12 epochs:  20%|██        | 2/10 [00:03<00:14,  1.80s/it]
# LightFM batch 12 epochs:  30%|███       | 3/10 [00:05<00:12,  1.81s/it]
# LightFM batch 12 epochs:  40%|████      | 4/10 [00:07<00:10,  1.82s/it]
# LightFM batch 12 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.84s/it]
# LightFM batch 12 epochs:  60%|██████    | 6/10 [00:11<00:08,  2.04s/it]
# LightFM batch 12 epochs:  70%|███████   | 7/10 [00:14<00:06,  2.20s/it]
# LightFM batch 12 epochs:  80%|████████  | 8/10 [00:16<00:04,  2.11s/it]
# LightFM batch 12 epochs:  90%|█████████ | 9/10 [00:18<00:02,  2.13s/it]
# LightFM batch 12 epochs: 100%|██████████| 10/10 [00:20<00:00,  2.05s/it]
# LightFM training batches:  17%|█▋        | 12/70 [04:19<20:30, 21.22s/it]
# LightFM batch 13 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 13 epochs:  10%|█         | 1/10 [00:01<00:15,  1.72s/it]
# LightFM batch 13 epochs:  20%|██        | 2/10 [00:04<00:17,  2.23s/it]
# LightFM batch 13 epochs:  30%|███       | 3/10 [00:06<00:14,  2.04s/it]
# LightFM batch 13 epochs:  40%|████      | 4/10 [00:07<00:11,  1.94s/it]
# LightFM batch 13 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.89s/it]
# LightFM batch 13 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.86s/it]
# LightFM batch 13 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.84s/it]
# LightFM batch 13 epochs:  80%|████████  | 8/10 [00:15<00:04,  2.03s/it]
# LightFM batch 13 epochs:  90%|█████████ | 9/10 [00:17<00:02,  2.03s/it]
# LightFM batch 13 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.97s/it]
# LightFM training batches:  19%|█▊        | 13/70 [04:40<19:52, 20.92s/it]
# LightFM batch 14 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 14 epochs:  10%|█         | 1/10 [00:01<00:15,  1.71s/it]
# LightFM batch 14 epochs:  20%|██        | 2/10 [00:03<00:13,  1.73s/it]
# LightFM batch 14 epochs:  30%|███       | 3/10 [00:05<00:12,  1.74s/it]
# LightFM batch 14 epochs:  40%|████      | 4/10 [00:07<00:11,  1.94s/it]
# LightFM batch 14 epochs:  50%|█████     | 5/10 [00:09<00:10,  2.01s/it]
# LightFM batch 14 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.92s/it]
# LightFM batch 14 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.87s/it]
# LightFM batch 14 epochs:  80%|████████  | 8/10 [00:14<00:03,  1.85s/it]
# LightFM batch 14 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.82s/it]
# LightFM batch 14 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.81s/it]
# LightFM training batches:  20%|██        | 14/70 [04:59<18:59, 20.34s/it]
# LightFM batch 15 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 15 epochs:  10%|█         | 1/10 [00:02<00:19,  2.18s/it]
# LightFM batch 15 epochs:  20%|██        | 2/10 [00:03<00:15,  1.89s/it]
# LightFM batch 15 epochs:  30%|███       | 3/10 [00:05<00:12,  1.79s/it]
# LightFM batch 15 epochs:  40%|████      | 4/10 [00:07<00:10,  1.76s/it]
# LightFM batch 15 epochs:  50%|█████     | 5/10 [00:08<00:08,  1.74s/it]
# LightFM batch 15 epochs:  60%|██████    | 6/10 [00:10<00:06,  1.73s/it]
# LightFM batch 15 epochs:  70%|███████   | 7/10 [00:12<00:05,  1.89s/it]
# LightFM batch 15 epochs:  80%|████████  | 8/10 [00:14<00:03,  1.95s/it]
# LightFM batch 15 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.88s/it]
# LightFM batch 15 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.82s/it]
# LightFM training batches:  21%|██▏       | 15/70 [05:18<18:22, 20.04s/it]
# LightFM batch 16 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 16 epochs:  10%|█         | 1/10 [00:01<00:14,  1.61s/it]
# LightFM batch 16 epochs:  20%|██        | 2/10 [00:03<00:13,  1.64s/it]
# LightFM batch 16 epochs:  30%|███       | 3/10 [00:05<00:11,  1.69s/it]
# LightFM batch 16 epochs:  40%|████      | 4/10 [00:07<00:12,  2.03s/it]
# LightFM batch 16 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.92s/it]
# LightFM batch 16 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.86s/it]
# LightFM batch 16 epochs:  70%|███████   | 7/10 [00:12<00:05,  1.81s/it]
# LightFM batch 16 epochs:  80%|████████  | 8/10 [00:14<00:03,  1.78s/it]
# LightFM batch 16 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.76s/it]
# LightFM batch 16 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.85s/it]
# LightFM training batches:  23%|██▎       | 16/70 [05:37<17:41, 19.66s/it]
# LightFM batch 17 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 17 epochs:  10%|█         | 1/10 [00:01<00:16,  1.81s/it]
# LightFM batch 17 epochs:  20%|██        | 2/10 [00:03<00:14,  1.76s/it]
# LightFM batch 17 epochs:  30%|███       | 3/10 [00:05<00:12,  1.74s/it]
# LightFM batch 17 epochs:  40%|████      | 4/10 [00:06<00:10,  1.74s/it]
# LightFM batch 17 epochs:  50%|█████     | 5/10 [00:08<00:08,  1.75s/it]
# LightFM batch 17 epochs:  60%|██████    | 6/10 [00:10<00:07,  1.76s/it]
# LightFM batch 17 epochs:  70%|███████   | 7/10 [00:13<00:06,  2.02s/it]
# LightFM batch 17 epochs:  80%|████████  | 8/10 [00:14<00:03,  1.93s/it]
# LightFM batch 17 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.88s/it]
# LightFM batch 17 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.83s/it]
# LightFM training batches:  24%|██▍       | 17/70 [05:56<17:16, 19.56s/it]
# LightFM batch 18 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 18 epochs:  10%|█         | 1/10 [00:02<00:20,  2.22s/it]
# LightFM batch 18 epochs:  20%|██        | 2/10 [00:04<00:17,  2.17s/it]
# LightFM batch 18 epochs:  30%|███       | 3/10 [00:07<00:17,  2.57s/it]
# LightFM batch 18 epochs:  40%|████      | 4/10 [00:09<00:13,  2.32s/it]
# LightFM batch 18 epochs:  50%|█████     | 5/10 [00:11<00:10,  2.18s/it]
# LightFM batch 18 epochs:  60%|██████    | 6/10 [00:13<00:08,  2.10s/it]
# LightFM batch 18 epochs:  70%|███████   | 7/10 [00:15<00:06,  2.05s/it]
# LightFM batch 18 epochs:  80%|████████  | 8/10 [00:17<00:04,  2.17s/it]
# LightFM batch 18 epochs:  90%|█████████ | 9/10 [00:19<00:02,  2.22s/it]
# LightFM batch 18 epochs: 100%|██████████| 10/10 [00:21<00:00,  2.14s/it]
# LightFM training batches:  26%|██▌       | 18/70 [06:18<17:42, 20.44s/it]
# LightFM batch 19 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 19 epochs:  10%|█         | 1/10 [00:01<00:14,  1.66s/it]
# LightFM batch 19 epochs:  20%|██        | 2/10 [00:03<00:13,  1.70s/it]
# LightFM batch 19 epochs:  30%|███       | 3/10 [00:05<00:12,  1.72s/it]
# LightFM batch 19 epochs:  40%|████      | 4/10 [00:07<00:11,  1.90s/it]
# LightFM batch 19 epochs:  50%|█████     | 5/10 [00:09<00:10,  2.00s/it]
# LightFM batch 19 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.92s/it]
# LightFM batch 19 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.87s/it]
# LightFM batch 19 epochs:  80%|████████  | 8/10 [00:14<00:03,  1.84s/it]
# LightFM batch 19 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.82s/it]
# LightFM batch 19 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.81s/it]
# LightFM training batches:  27%|██▋       | 19/70 [06:37<16:59, 19.99s/it]
# LightFM batch 20 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 20 epochs:  10%|█         | 1/10 [00:02<00:20,  2.33s/it]
# LightFM batch 20 epochs:  20%|██        | 2/10 [00:04<00:16,  2.02s/it]
# LightFM batch 20 epochs:  30%|███       | 3/10 [00:05<00:13,  1.92s/it]
# LightFM batch 20 epochs:  40%|████      | 4/10 [00:07<00:11,  1.87s/it]
# LightFM batch 20 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.85s/it]
# LightFM batch 20 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.84s/it]
# LightFM batch 20 epochs:  70%|███████   | 7/10 [00:14<00:06,  2.11s/it]
# LightFM batch 20 epochs:  80%|████████  | 8/10 [00:15<00:04,  2.01s/it]
# LightFM batch 20 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.95s/it]
# LightFM batch 20 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.91s/it]
# LightFM training batches:  29%|██▊       | 20/70 [06:58<16:45, 20.10s/it]
# LightFM batch 21 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 21 epochs:  10%|█         | 1/10 [00:01<00:15,  1.68s/it]
# LightFM batch 21 epochs:  20%|██        | 2/10 [00:03<00:13,  1.71s/it]
# LightFM batch 21 epochs:  30%|███       | 3/10 [00:05<00:14,  2.05s/it]
# LightFM batch 21 epochs:  40%|████      | 4/10 [00:07<00:11,  1.99s/it]
# LightFM batch 21 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.91s/it]
# LightFM batch 21 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.86s/it]
# LightFM batch 21 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.83s/it]
# LightFM batch 21 epochs:  80%|████████  | 8/10 [00:14<00:03,  1.82s/it]
# LightFM batch 21 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.88s/it]
# LightFM batch 21 epochs: 100%|██████████| 10/10 [00:19<00:00,  2.04s/it]
# LightFM training batches:  30%|███       | 21/70 [07:18<16:21, 20.03s/it]
# LightFM batch 22 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 22 epochs:  10%|█         | 1/10 [00:01<00:16,  1.79s/it]
# LightFM batch 22 epochs:  20%|██        | 2/10 [00:03<00:14,  1.83s/it]
# LightFM batch 22 epochs:  30%|███       | 3/10 [00:05<00:12,  1.85s/it]
# LightFM batch 22 epochs:  40%|████      | 4/10 [00:07<00:11,  1.87s/it]
# LightFM batch 22 epochs:  50%|█████     | 5/10 [00:09<00:10,  2.01s/it]
# LightFM batch 22 epochs:  60%|██████    | 6/10 [00:12<00:08,  2.13s/it]
# LightFM batch 22 epochs:  70%|███████   | 7/10 [00:13<00:06,  2.06s/it]
# LightFM batch 22 epochs:  80%|████████  | 8/10 [00:15<00:04,  2.01s/it]
# LightFM batch 22 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.97s/it]
# LightFM batch 22 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.95s/it]
# LightFM training batches:  31%|███▏      | 22/70 [07:38<16:04, 20.10s/it]
# LightFM batch 23 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 23 epochs:  10%|█         | 1/10 [00:02<00:21,  2.42s/it]
# LightFM batch 23 epochs:  20%|██        | 2/10 [00:04<00:17,  2.21s/it]
# LightFM batch 23 epochs:  30%|███       | 3/10 [00:06<00:14,  2.05s/it]
# LightFM batch 23 epochs:  40%|████      | 4/10 [00:08<00:11,  1.98s/it]
# LightFM batch 23 epochs:  50%|█████     | 5/10 [00:10<00:09,  1.94s/it]
# LightFM batch 23 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.91s/it]
# LightFM batch 23 epochs:  70%|███████   | 7/10 [00:14<00:06,  2.06s/it]
# LightFM batch 23 epochs:  80%|████████  | 8/10 [00:16<00:04,  2.13s/it]
# LightFM batch 23 epochs:  90%|█████████ | 9/10 [00:18<00:02,  2.06s/it]
# LightFM batch 23 epochs: 100%|██████████| 10/10 [00:20<00:00,  2.00s/it]
# LightFM training batches:  33%|███▎      | 23/70 [07:59<15:57, 20.36s/it]
# LightFM batch 24 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 24 epochs:  10%|█         | 1/10 [00:01<00:15,  1.70s/it]
# LightFM batch 24 epochs:  20%|██        | 2/10 [00:03<00:13,  1.72s/it]
# LightFM batch 24 epochs:  30%|███       | 3/10 [00:05<00:13,  1.96s/it]
# LightFM batch 24 epochs:  40%|████      | 4/10 [00:07<00:12,  2.04s/it]
# LightFM batch 24 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.95s/it]
# LightFM batch 24 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.90s/it]
# LightFM batch 24 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.88s/it]
# LightFM batch 24 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.85s/it]
# LightFM batch 24 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.87s/it]
# LightFM batch 24 epochs: 100%|██████████| 10/10 [00:19<00:00,  2.09s/it]
# LightFM training batches:  34%|███▍      | 24/70 [08:19<15:33, 20.30s/it]
# LightFM batch 25 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 25 epochs:  10%|█         | 1/10 [00:01<00:15,  1.70s/it]
# LightFM batch 25 epochs:  20%|██        | 2/10 [00:03<00:13,  1.73s/it]
# LightFM batch 25 epochs:  30%|███       | 3/10 [00:05<00:12,  1.76s/it]
# LightFM batch 25 epochs:  40%|████      | 4/10 [00:07<00:10,  1.77s/it]
# LightFM batch 25 epochs:  50%|█████     | 5/10 [00:08<00:08,  1.78s/it]
# LightFM batch 25 epochs:  60%|██████    | 6/10 [00:11<00:08,  2.07s/it]
# LightFM batch 25 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.98s/it]
# LightFM batch 25 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.92s/it]
# LightFM batch 25 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.88s/it]
# LightFM batch 25 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.86s/it]
# LightFM training batches:  36%|███▌      | 25/70 [08:38<14:59, 19.98s/it]
# LightFM batch 26 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 26 epochs:  10%|█         | 1/10 [00:01<00:15,  1.70s/it]
# LightFM batch 26 epochs:  20%|██        | 2/10 [00:04<00:18,  2.27s/it]
# LightFM batch 26 epochs:  30%|███       | 3/10 [00:06<00:14,  2.05s/it]
# LightFM batch 26 epochs:  40%|████      | 4/10 [00:07<00:11,  1.95s/it]
# LightFM batch 26 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.90s/it]
# LightFM batch 26 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.87s/it]
# LightFM batch 26 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.85s/it]
# LightFM batch 26 epochs:  80%|████████  | 8/10 [00:15<00:04,  2.02s/it]
# LightFM batch 26 epochs:  90%|█████████ | 9/10 [00:17<00:02,  2.04s/it]
# LightFM batch 26 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.97s/it]
# LightFM training batches:  37%|███▋      | 26/70 [08:59<14:43, 20.07s/it]
# LightFM batch 27 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 27 epochs:  10%|█         | 1/10 [00:01<00:15,  1.75s/it]
# LightFM batch 27 epochs:  20%|██        | 2/10 [00:03<00:15,  1.98s/it]
# LightFM batch 27 epochs:  30%|███       | 3/10 [00:07<00:19,  2.80s/it]
# LightFM batch 27 epochs:  40%|████      | 4/10 [00:11<00:18,  3.14s/it]
# LightFM batch 27 epochs:  50%|█████     | 5/10 [00:13<00:14,  2.89s/it]
# LightFM batch 27 epochs:  60%|██████    | 6/10 [00:15<00:10,  2.54s/it]
# LightFM batch 27 epochs:  70%|███████   | 7/10 [00:17<00:06,  2.31s/it]
# LightFM batch 27 epochs:  80%|████████  | 8/10 [00:19<00:04,  2.16s/it]
# LightFM batch 27 epochs:  90%|█████████ | 9/10 [00:21<00:02,  2.25s/it]
# LightFM batch 27 epochs: 100%|██████████| 10/10 [00:23<00:00,  2.22s/it]
# LightFM training batches:  39%|███▊      | 27/70 [09:23<15:20, 21.40s/it]
# LightFM batch 28 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 28 epochs:  10%|█         | 1/10 [00:01<00:15,  1.69s/it]
# LightFM batch 28 epochs:  20%|██        | 2/10 [00:03<00:13,  1.71s/it]
# LightFM batch 28 epochs:  30%|███       | 3/10 [00:05<00:12,  1.73s/it]
# LightFM batch 28 epochs:  40%|████      | 4/10 [00:06<00:10,  1.74s/it]
# LightFM batch 28 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.88s/it]
# LightFM batch 28 epochs:  60%|██████    | 6/10 [00:11<00:08,  2.02s/it]
# LightFM batch 28 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.94s/it]
# LightFM batch 28 epochs:  80%|████████  | 8/10 [00:14<00:03,  1.89s/it]
# LightFM batch 28 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.86s/it]
# LightFM batch 28 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.83s/it]
# LightFM training batches:  40%|████      | 28/70 [09:42<14:29, 20.70s/it]
# LightFM batch 29 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 29 epochs:  10%|█         | 1/10 [00:01<00:17,  1.96s/it]
# LightFM batch 29 epochs:  20%|██        | 2/10 [00:04<00:17,  2.24s/it]
# LightFM batch 29 epochs:  30%|███       | 3/10 [00:06<00:14,  2.04s/it]
# LightFM batch 29 epochs:  40%|████      | 4/10 [00:07<00:11,  1.94s/it]
# LightFM batch 29 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.90s/it]
# LightFM batch 29 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.88s/it]
# LightFM batch 29 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.87s/it]
# LightFM batch 29 epochs:  80%|████████  | 8/10 [00:16<00:04,  2.12s/it]
# LightFM batch 29 epochs:  90%|█████████ | 9/10 [00:17<00:02,  2.03s/it]
# LightFM batch 29 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.97s/it]
# LightFM training batches:  41%|████▏     | 29/70 [10:03<14:05, 20.63s/it]
# LightFM batch 30 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 30 epochs:  10%|█         | 1/10 [00:01<00:15,  1.71s/it]
# LightFM batch 30 epochs:  20%|██        | 2/10 [00:03<00:13,  1.75s/it]
# LightFM batch 30 epochs:  30%|███       | 3/10 [00:05<00:12,  1.76s/it]
# LightFM batch 30 epochs:  40%|████      | 4/10 [00:07<00:12,  2.13s/it]
# LightFM batch 30 epochs:  50%|█████     | 5/10 [00:09<00:10,  2.02s/it]
# LightFM batch 30 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.95s/it]
# LightFM batch 30 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.91s/it]
# LightFM batch 30 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.88s/it]
# LightFM batch 30 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.86s/it]
# LightFM batch 30 epochs: 100%|██████████| 10/10 [00:19<00:00,  2.03s/it]
# LightFM training batches:  43%|████▎     | 30/70 [10:23<13:37, 20.45s/it]
# LightFM batch 31 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 31 epochs:  10%|█         | 1/10 [00:01<00:16,  1.81s/it]
# LightFM batch 31 epochs:  20%|██        | 2/10 [00:03<00:14,  1.83s/it]
# LightFM batch 31 epochs:  30%|███       | 3/10 [00:05<00:13,  1.86s/it]
# LightFM batch 31 epochs:  40%|████      | 4/10 [00:07<00:11,  1.87s/it]
# LightFM batch 31 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.88s/it]
# LightFM batch 31 epochs:  60%|██████    | 6/10 [00:12<00:08,  2.15s/it]
# LightFM batch 31 epochs:  70%|███████   | 7/10 [00:14<00:06,  2.10s/it]
# LightFM batch 31 epochs:  80%|████████  | 8/10 [00:15<00:04,  2.04s/it]
# LightFM batch 31 epochs:  90%|█████████ | 9/10 [00:17<00:02,  2.00s/it]
# LightFM batch 31 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.98s/it]
# LightFM training batches:  44%|████▍     | 31/70 [10:43<13:21, 20.55s/it]
# LightFM batch 32 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 32 epochs:  10%|█         | 1/10 [00:01<00:15,  1.76s/it]
# LightFM batch 32 epochs:  20%|██        | 2/10 [00:04<00:18,  2.31s/it]
# LightFM batch 32 epochs:  30%|███       | 3/10 [00:06<00:14,  2.10s/it]
# LightFM batch 32 epochs:  40%|████      | 4/10 [00:08<00:12,  2.00s/it]
# LightFM batch 32 epochs:  50%|█████     | 5/10 [00:10<00:09,  1.96s/it]
# LightFM batch 32 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.93s/it]
# LightFM batch 32 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.91s/it]
# LightFM batch 32 epochs:  80%|████████  | 8/10 [00:16<00:04,  2.17s/it]
# LightFM batch 32 epochs:  90%|█████████ | 9/10 [00:18<00:02,  2.08s/it]
# LightFM batch 32 epochs: 100%|██████████| 10/10 [00:20<00:00,  2.03s/it]
# LightFM training batches:  46%|████▌     | 32/70 [11:04<13:04, 20.65s/it]
# LightFM batch 33 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 33 epochs:  10%|█         | 1/10 [00:01<00:15,  1.72s/it]
# LightFM batch 33 epochs:  20%|██        | 2/10 [00:03<00:14,  1.76s/it]
# LightFM batch 33 epochs:  30%|███       | 3/10 [00:05<00:12,  1.79s/it]
# LightFM batch 33 epochs:  40%|████      | 4/10 [00:07<00:12,  2.11s/it]
# LightFM batch 33 epochs:  50%|█████     | 5/10 [00:09<00:10,  2.01s/it]
# LightFM batch 33 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.95s/it]
# LightFM batch 33 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.91s/it]
# LightFM batch 33 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.89s/it]
# LightFM batch 33 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.87s/it]
# LightFM batch 33 epochs: 100%|██████████| 10/10 [00:19<00:00,  2.10s/it]
# LightFM training batches:  47%|████▋     | 33/70 [11:25<12:40, 20.57s/it]
# LightFM batch 34 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 34 epochs:  10%|█         | 1/10 [00:01<00:15,  1.74s/it]
# LightFM batch 34 epochs:  20%|██        | 2/10 [00:03<00:14,  1.79s/it]
# LightFM batch 34 epochs:  30%|███       | 3/10 [00:05<00:12,  1.81s/it]
# LightFM batch 34 epochs:  40%|████      | 4/10 [00:07<00:10,  1.83s/it]
# LightFM batch 34 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.84s/it]
# LightFM batch 34 epochs:  60%|██████    | 6/10 [00:11<00:08,  2.10s/it]
# LightFM batch 34 epochs:  70%|███████   | 7/10 [00:13<00:06,  2.02s/it]
# LightFM batch 34 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.97s/it]
# LightFM batch 34 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.94s/it]
# LightFM batch 34 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.92s/it]
# LightFM training batches:  49%|████▊     | 34/70 [11:44<12:11, 20.33s/it]
# LightFM batch 35 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 35 epochs:  10%|█         | 1/10 [00:01<00:17,  1.96s/it]
# LightFM batch 35 epochs:  20%|██        | 2/10 [00:04<00:18,  2.29s/it]
# LightFM batch 35 epochs:  30%|███       | 3/10 [00:06<00:14,  2.11s/it]
# LightFM batch 35 epochs:  40%|████      | 4/10 [00:08<00:12,  2.03s/it]
# LightFM batch 35 epochs:  50%|█████     | 5/10 [00:10<00:09,  2.00s/it]
# LightFM batch 35 epochs:  60%|██████    | 6/10 [00:12<00:07,  1.97s/it]
# LightFM batch 35 epochs:  70%|███████   | 7/10 [00:14<00:06,  2.02s/it]
# LightFM batch 35 epochs:  80%|████████  | 8/10 [00:16<00:04,  2.17s/it]
# LightFM batch 35 epochs:  90%|█████████ | 9/10 [00:18<00:02,  2.09s/it]
# LightFM batch 35 epochs: 100%|██████████| 10/10 [00:20<00:00,  2.05s/it]
# LightFM training batches:  50%|█████     | 35/70 [12:06<12:01, 20.60s/it]
# LightFM batch 36 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 36 epochs:  10%|█         | 1/10 [00:01<00:14,  1.65s/it]
# LightFM batch 36 epochs:  20%|██        | 2/10 [00:03<00:13,  1.70s/it]
# LightFM batch 36 epochs:  30%|███       | 3/10 [00:05<00:13,  1.86s/it]
# LightFM batch 36 epochs:  40%|████      | 4/10 [00:07<00:12,  2.00s/it]
# LightFM batch 36 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.91s/it]
# LightFM batch 36 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.86s/it]
# LightFM batch 36 epochs:  70%|███████   | 7/10 [00:12<00:05,  1.84s/it]
# LightFM batch 36 epochs:  80%|████████  | 8/10 [00:14<00:03,  1.82s/it]
# LightFM batch 36 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.80s/it]
# LightFM batch 36 epochs: 100%|██████████| 10/10 [00:19<00:00,  2.04s/it]
# LightFM training batches:  51%|█████▏    | 36/70 [12:25<11:30, 20.32s/it]
# LightFM batch 37 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 37 epochs:  10%|█         | 1/10 [00:01<00:16,  1.78s/it]
# LightFM batch 37 epochs:  20%|██        | 2/10 [00:03<00:14,  1.83s/it]
# LightFM batch 37 epochs:  30%|███       | 3/10 [00:05<00:13,  1.86s/it]
# LightFM batch 37 epochs:  40%|████      | 4/10 [00:07<00:11,  1.88s/it]
# LightFM batch 37 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.94s/it]
# LightFM batch 37 epochs:  60%|██████    | 6/10 [00:12<00:08,  2.13s/it]
# LightFM batch 37 epochs:  70%|███████   | 7/10 [00:13<00:06,  2.06s/it]
# LightFM batch 37 epochs:  80%|████████  | 8/10 [00:15<00:04,  2.01s/it]
# LightFM batch 37 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.99s/it]
# LightFM batch 37 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.97s/it]
# LightFM training batches:  53%|█████▎    | 37/70 [12:46<11:10, 20.32s/it]
# LightFM batch 38 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 38 epochs:  10%|█         | 1/10 [00:02<00:20,  2.23s/it]
# LightFM batch 38 epochs:  20%|██        | 2/10 [00:04<00:17,  2.14s/it]
# LightFM batch 38 epochs:  30%|███       | 3/10 [00:06<00:13,  1.99s/it]
# LightFM batch 38 epochs:  40%|████      | 4/10 [00:07<00:11,  1.94s/it]
# LightFM batch 38 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.90s/it]
# LightFM batch 38 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.87s/it]
# LightFM batch 38 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.96s/it]
# LightFM batch 38 epochs:  80%|████████  | 8/10 [00:16<00:04,  2.07s/it]
# LightFM batch 38 epochs:  90%|█████████ | 9/10 [00:17<00:01,  2.00s/it]
# LightFM batch 38 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.95s/it]
# LightFM training batches:  54%|█████▍    | 38/70 [13:06<10:50, 20.33s/it]
# LightFM batch 39 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 39 epochs:  10%|█         | 1/10 [00:01<00:14,  1.65s/it]
# LightFM batch 39 epochs:  20%|██        | 2/10 [00:03<00:13,  1.72s/it]
# LightFM batch 39 epochs:  30%|███       | 3/10 [00:05<00:13,  1.87s/it]
# LightFM batch 39 epochs:  40%|████      | 4/10 [00:07<00:12,  2.02s/it]
# LightFM batch 39 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.93s/it]
# LightFM batch 39 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.88s/it]
# LightFM batch 39 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.84s/it]
# LightFM batch 39 epochs:  80%|████████  | 8/10 [00:14<00:03,  1.82s/it]
# LightFM batch 39 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.81s/it]
# LightFM batch 39 epochs: 100%|██████████| 10/10 [00:19<00:00,  2.04s/it]
# LightFM training batches:  56%|█████▌    | 39/70 [13:26<10:24, 20.16s/it]
# LightFM batch 40 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 40 epochs:  10%|█         | 1/10 [00:01<00:15,  1.70s/it]
# LightFM batch 40 epochs:  20%|██        | 2/10 [00:03<00:13,  1.74s/it]
# LightFM batch 40 epochs:  30%|███       | 3/10 [00:05<00:12,  1.75s/it]
# LightFM batch 40 epochs:  40%|████      | 4/10 [00:07<00:10,  1.77s/it]
# LightFM batch 40 epochs:  50%|█████     | 5/10 [00:08<00:08,  1.77s/it]
# LightFM batch 40 epochs:  60%|██████    | 6/10 [00:11<00:08,  2.04s/it]
# LightFM batch 40 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.96s/it]
# LightFM batch 40 epochs:  80%|████████  | 8/10 [00:14<00:03,  1.91s/it]
# LightFM batch 40 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.88s/it]
# LightFM batch 40 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.86s/it]
# LightFM training batches:  57%|█████▋    | 40/70 [13:45<09:56, 19.87s/it]
# LightFM batch 41 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 41 epochs:  10%|█         | 1/10 [00:01<00:14,  1.64s/it]
# LightFM batch 41 epochs:  20%|██        | 2/10 [00:04<00:16,  2.12s/it]
# LightFM batch 41 epochs:  30%|███       | 3/10 [00:05<00:13,  1.94s/it]
# LightFM batch 41 epochs:  40%|████      | 4/10 [00:07<00:11,  1.86s/it]
# LightFM batch 41 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.81s/it]
# LightFM batch 41 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.79s/it]
# LightFM batch 41 epochs:  70%|███████   | 7/10 [00:12<00:05,  1.77s/it]
# LightFM batch 41 epochs:  80%|████████  | 8/10 [00:14<00:03,  1.85s/it]
# LightFM batch 41 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.98s/it]
# LightFM batch 41 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.91s/it]
# LightFM training batches:  59%|█████▊    | 41/70 [14:04<09:31, 19.72s/it]
# LightFM batch 42 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 42 epochs:  10%|█         | 1/10 [00:01<00:14,  1.62s/it]
# LightFM batch 42 epochs:  20%|██        | 2/10 [00:03<00:13,  1.68s/it]
# LightFM batch 42 epochs:  30%|███       | 3/10 [00:05<00:11,  1.70s/it]
# LightFM batch 42 epochs:  40%|████      | 4/10 [00:06<00:10,  1.74s/it]
# LightFM batch 42 epochs:  50%|█████     | 5/10 [00:09<00:10,  2.01s/it]
# LightFM batch 42 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.93s/it]
# LightFM batch 42 epochs:  70%|███████   | 7/10 [00:12<00:05,  1.87s/it]
# LightFM batch 42 epochs:  80%|████████  | 8/10 [00:14<00:03,  1.83s/it]
# LightFM batch 42 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.81s/it]
# LightFM batch 42 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.79s/it]
# LightFM training batches:  60%|██████    | 42/70 [14:23<09:04, 19.43s/it]
# LightFM batch 43 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 43 epochs:  10%|█         | 1/10 [00:02<00:21,  2.43s/it]
# LightFM batch 43 epochs:  20%|██        | 2/10 [00:04<00:16,  2.02s/it]
# LightFM batch 43 epochs:  30%|███       | 3/10 [00:05<00:13,  1.90s/it]
# LightFM batch 43 epochs:  40%|████      | 4/10 [00:07<00:11,  1.84s/it]
# LightFM batch 43 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.82s/it]
# LightFM batch 43 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.80s/it]
# LightFM batch 43 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.94s/it]
# LightFM batch 43 epochs:  80%|████████  | 8/10 [00:15<00:03,  2.00s/it]
# LightFM batch 43 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.93s/it]
# LightFM batch 43 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.88s/it]
# LightFM training batches:  61%|██████▏   | 43/70 [14:43<08:46, 19.51s/it]
# LightFM batch 44 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 44 epochs:  10%|█         | 1/10 [00:01<00:14,  1.61s/it]
# LightFM batch 44 epochs:  20%|██        | 2/10 [00:03<00:13,  1.65s/it]
# LightFM batch 44 epochs:  30%|███       | 3/10 [00:05<00:12,  1.75s/it]
# LightFM batch 44 epochs:  40%|████      | 4/10 [00:07<00:11,  1.96s/it]
# LightFM batch 44 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.86s/it]
# LightFM batch 44 epochs:  60%|██████    | 6/10 [00:10<00:07,  1.80s/it]
# LightFM batch 44 epochs:  70%|███████   | 7/10 [00:12<00:05,  1.77s/it]
# LightFM batch 44 epochs:  80%|████████  | 8/10 [00:14<00:03,  1.75s/it]
# LightFM batch 44 epochs:  90%|█████████ | 9/10 [00:15<00:01,  1.74s/it]
# LightFM batch 44 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.89s/it]
# LightFM training batches:  63%|██████▎   | 44/70 [15:02<08:21, 19.28s/it]
# LightFM batch 45 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 45 epochs:  10%|█         | 1/10 [00:01<00:14,  1.65s/it]
# LightFM batch 45 epochs:  20%|██        | 2/10 [00:03<00:13,  1.67s/it]
# LightFM batch 45 epochs:  30%|███       | 3/10 [00:05<00:11,  1.69s/it]
# LightFM batch 45 epochs:  40%|████      | 4/10 [00:06<00:10,  1.71s/it]
# LightFM batch 45 epochs:  50%|█████     | 5/10 [00:08<00:08,  1.72s/it]
# LightFM batch 45 epochs:  60%|██████    | 6/10 [00:10<00:07,  1.80s/it]
# LightFM batch 45 epochs:  70%|███████   | 7/10 [00:12<00:05,  1.98s/it]
# LightFM batch 45 epochs:  80%|████████  | 8/10 [00:14<00:03,  1.90s/it]
# LightFM batch 45 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.86s/it]
# LightFM batch 45 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.83s/it]
# LightFM training batches:  64%|██████▍   | 45/70 [15:21<08:00, 19.21s/it]
# LightFM batch 46 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 46 epochs:  10%|█         | 1/10 [00:01<00:15,  1.75s/it]
# LightFM batch 46 epochs:  20%|██        | 2/10 [00:03<00:15,  1.89s/it]
# LightFM batch 46 epochs:  30%|███       | 3/10 [00:06<00:15,  2.15s/it]
# LightFM batch 46 epochs:  40%|████      | 4/10 [00:08<00:12,  2.03s/it]
# LightFM batch 46 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.97s/it]
# LightFM batch 46 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.94s/it]
# LightFM batch 46 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.91s/it]
# LightFM batch 46 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.92s/it]
# LightFM batch 46 epochs:  90%|█████████ | 9/10 [00:18<00:02,  2.13s/it]
# LightFM batch 46 epochs: 100%|██████████| 10/10 [00:20<00:00,  2.05s/it]
# LightFM training batches:  66%|██████▌   | 46/70 [15:41<07:51, 19.64s/it]
# LightFM batch 47 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 47 epochs:  10%|█         | 1/10 [00:01<00:15,  1.69s/it]
# LightFM batch 47 epochs:  20%|██        | 2/10 [00:03<00:13,  1.75s/it]
# LightFM batch 47 epochs:  30%|███       | 3/10 [00:05<00:12,  1.76s/it]
# LightFM batch 47 epochs:  40%|████      | 4/10 [00:07<00:10,  1.82s/it]
# LightFM batch 47 epochs:  50%|█████     | 5/10 [00:09<00:10,  2.05s/it]
# LightFM batch 47 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.96s/it]
# LightFM batch 47 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.92s/it]
# LightFM batch 47 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.88s/it]
# LightFM batch 47 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.86s/it]
# LightFM batch 47 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.85s/it]
# LightFM training batches:  67%|██████▋   | 47/70 [16:00<07:29, 19.52s/it]
# LightFM batch 48 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 48 epochs:  10%|█         | 1/10 [00:02<00:20,  2.22s/it]
# LightFM batch 48 epochs:  20%|██        | 2/10 [00:03<00:15,  1.91s/it]
# LightFM batch 48 epochs:  30%|███       | 3/10 [00:05<00:12,  1.81s/it]
# LightFM batch 48 epochs:  40%|████      | 4/10 [00:07<00:10,  1.78s/it]
# LightFM batch 48 epochs:  50%|█████     | 5/10 [00:09<00:08,  1.77s/it]
# LightFM batch 48 epochs:  60%|██████    | 6/10 [00:10<00:07,  1.75s/it]
# LightFM batch 48 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.93s/it]
# LightFM batch 48 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.95s/it]
# LightFM batch 48 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.89s/it]
# LightFM batch 48 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.85s/it]
# LightFM training batches:  69%|██████▊   | 48/70 [16:20<07:08, 19.49s/it]
# LightFM batch 49 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 49 epochs:  10%|█         | 1/10 [00:01<00:16,  1.79s/it]
# LightFM batch 49 epochs:  20%|██        | 2/10 [00:03<00:14,  1.84s/it]
# LightFM batch 49 epochs:  30%|███       | 3/10 [00:06<00:14,  2.14s/it]
# LightFM batch 49 epochs:  40%|████      | 4/10 [00:08<00:12,  2.10s/it]
# LightFM batch 49 epochs:  50%|█████     | 5/10 [00:10<00:10,  2.03s/it]
# LightFM batch 49 epochs:  60%|██████    | 6/10 [00:12<00:07,  1.99s/it]
# LightFM batch 49 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.97s/it]
# LightFM batch 49 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.95s/it]
# LightFM batch 49 epochs:  90%|█████████ | 9/10 [00:18<00:02,  2.16s/it]
# LightFM batch 49 epochs: 100%|██████████| 10/10 [00:20<00:00,  2.11s/it]
# LightFM training batches:  70%|███████   | 49/70 [16:41<06:59, 19.96s/it]
# LightFM batch 50 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 50 epochs:  10%|█         | 1/10 [00:01<00:15,  1.72s/it]
# LightFM batch 50 epochs:  20%|██        | 2/10 [00:03<00:14,  1.78s/it]
# LightFM batch 50 epochs:  30%|███       | 3/10 [00:05<00:12,  1.81s/it]
# LightFM batch 50 epochs:  40%|████      | 4/10 [00:07<00:10,  1.82s/it]
# LightFM batch 50 epochs:  50%|█████     | 5/10 [00:09<00:10,  2.10s/it]
# LightFM batch 50 epochs:  60%|██████    | 6/10 [00:11<00:08,  2.02s/it]
# LightFM batch 50 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.97s/it]
# LightFM batch 50 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.92s/it]
# LightFM batch 50 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.90s/it]
# LightFM batch 50 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.88s/it]
# LightFM training batches:  71%|███████▏  | 50/70 [17:01<06:37, 19.88s/it]
# LightFM batch 51 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 51 epochs:  10%|█         | 1/10 [00:02<00:22,  2.48s/it]
# LightFM batch 51 epochs:  20%|██        | 2/10 [00:04<00:16,  2.07s/it]
# LightFM batch 51 epochs:  30%|███       | 3/10 [00:06<00:13,  1.95s/it]
# LightFM batch 51 epochs:  40%|████      | 4/10 [00:07<00:11,  1.91s/it]
# LightFM batch 51 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.88s/it]
# LightFM batch 51 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.86s/it]
# LightFM batch 51 epochs:  70%|███████   | 7/10 [00:14<00:06,  2.11s/it]
# LightFM batch 51 epochs:  80%|████████  | 8/10 [00:16<00:04,  2.03s/it]
# LightFM batch 51 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.97s/it]
# LightFM batch 51 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.93s/it]
# LightFM training batches:  73%|███████▎  | 51/70 [17:21<06:20, 20.02s/it]
# LightFM batch 52 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 52 epochs:  10%|█         | 1/10 [00:01<00:15,  1.69s/it]
# LightFM batch 52 epochs:  20%|██        | 2/10 [00:03<00:13,  1.74s/it]
# LightFM batch 52 epochs:  30%|███       | 3/10 [00:06<00:14,  2.12s/it]
# LightFM batch 52 epochs:  40%|████      | 4/10 [00:07<00:11,  2.00s/it]
# LightFM batch 52 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.93s/it]
# LightFM batch 52 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.89s/it]
# LightFM batch 52 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.87s/it]
# LightFM batch 52 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.86s/it]
# LightFM batch 52 epochs:  90%|█████████ | 9/10 [00:17<00:02,  2.03s/it]
# LightFM batch 52 epochs: 100%|██████████| 10/10 [00:19<00:00,  2.04s/it]
# LightFM training batches:  74%|███████▍  | 52/70 [17:41<06:01, 20.08s/it]
# LightFM batch 53 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 53 epochs:  10%|█         | 1/10 [00:01<00:15,  1.77s/it]
# LightFM batch 53 epochs:  20%|██        | 2/10 [00:03<00:14,  1.83s/it]
# LightFM batch 53 epochs:  30%|███       | 3/10 [00:05<00:12,  1.85s/it]
# LightFM batch 53 epochs:  40%|████      | 4/10 [00:07<00:11,  1.87s/it]
# LightFM batch 53 epochs:  50%|█████     | 5/10 [00:10<00:10,  2.16s/it]
# LightFM batch 53 epochs:  60%|██████    | 6/10 [00:11<00:08,  2.07s/it]
# LightFM batch 53 epochs:  70%|███████   | 7/10 [00:13<00:06,  2.01s/it]
# LightFM batch 53 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.98s/it]
# LightFM batch 53 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.95s/it]
# LightFM batch 53 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.94s/it]
# LightFM training batches:  76%|███████▌  | 53/70 [18:01<05:42, 20.12s/it]
# LightFM batch 54 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 54 epochs:  10%|█         | 1/10 [00:02<00:21,  2.39s/it]
# LightFM batch 54 epochs:  20%|██        | 2/10 [00:04<00:16,  2.05s/it]
# LightFM batch 54 epochs:  30%|███       | 3/10 [00:06<00:13,  1.95s/it]
# LightFM batch 54 epochs:  40%|████      | 4/10 [00:07<00:11,  1.91s/it]
# LightFM batch 54 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.89s/it]
# LightFM batch 54 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.88s/it]
# LightFM batch 54 epochs:  70%|███████   | 7/10 [00:14<00:06,  2.13s/it]
# LightFM batch 54 epochs:  80%|████████  | 8/10 [00:16<00:04,  2.05s/it]
# LightFM batch 54 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.99s/it]
# LightFM batch 54 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.96s/it]
# LightFM training batches:  77%|███████▋  | 54/70 [18:22<05:24, 20.28s/it]
# LightFM batch 55 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 55 epochs:  10%|█         | 1/10 [00:01<00:15,  1.72s/it]
# LightFM batch 55 epochs:  20%|██        | 2/10 [00:03<00:14,  1.81s/it]
# LightFM batch 55 epochs:  30%|███       | 3/10 [00:06<00:14,  2.13s/it]
# LightFM batch 55 epochs:  40%|████      | 4/10 [00:07<00:12,  2.02s/it]
# LightFM batch 55 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.95s/it]
# LightFM batch 55 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.91s/it]
# LightFM batch 55 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.89s/it]
# LightFM batch 55 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.87s/it]
# LightFM batch 55 epochs:  90%|█████████ | 9/10 [00:17<00:02,  2.11s/it]
# LightFM batch 55 epochs: 100%|██████████| 10/10 [00:19<00:00,  2.03s/it]
# LightFM training batches:  79%|███████▊  | 55/70 [18:42<05:04, 20.31s/it]
# LightFM batch 56 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 56 epochs:  10%|█         | 1/10 [00:01<00:15,  1.73s/it]
# LightFM batch 56 epochs:  20%|██        | 2/10 [00:03<00:14,  1.80s/it]
# LightFM batch 56 epochs:  30%|███       | 3/10 [00:05<00:12,  1.81s/it]
# LightFM batch 56 epochs:  40%|████      | 4/10 [00:07<00:10,  1.82s/it]
# LightFM batch 56 epochs:  50%|█████     | 5/10 [00:09<00:10,  2.11s/it]
# LightFM batch 56 epochs:  60%|██████    | 6/10 [00:11<00:08,  2.03s/it]
# LightFM batch 56 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.97s/it]
# LightFM batch 56 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.92s/it]
# LightFM batch 56 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.90s/it]
# LightFM batch 56 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.89s/it]
# LightFM training batches:  80%|████████  | 56/70 [19:02<04:41, 20.13s/it]
# LightFM batch 57 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 57 epochs:  10%|█         | 1/10 [00:02<00:19,  2.21s/it]
# LightFM batch 57 epochs:  20%|██        | 2/10 [00:03<00:15,  1.93s/it]
# LightFM batch 57 epochs:  30%|███       | 3/10 [00:05<00:12,  1.85s/it]
# LightFM batch 57 epochs:  40%|████      | 4/10 [00:07<00:10,  1.82s/it]
# LightFM batch 57 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.81s/it]
# LightFM batch 57 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.80s/it]
# LightFM batch 57 epochs:  70%|███████   | 7/10 [00:13<00:06,  2.05s/it]
# LightFM batch 57 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.97s/it]
# LightFM batch 57 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.91s/it]
# LightFM batch 57 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.88s/it]
# LightFM training batches:  81%|████████▏ | 57/70 [19:22<04:20, 20.06s/it]
# LightFM batch 58 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 58 epochs:  10%|█         | 1/10 [00:01<00:15,  1.74s/it]
# LightFM batch 58 epochs:  20%|██        | 2/10 [00:03<00:14,  1.80s/it]
# LightFM batch 58 epochs:  30%|███       | 3/10 [00:06<00:15,  2.18s/it]
# LightFM batch 58 epochs:  40%|████      | 4/10 [00:08<00:12,  2.05s/it]
# LightFM batch 58 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.99s/it]
# LightFM batch 58 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.95s/it]
# LightFM batch 58 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.93s/it]
# LightFM batch 58 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.91s/it]
# LightFM batch 58 epochs:  90%|█████████ | 9/10 [00:18<00:02,  2.14s/it]
# LightFM batch 58 epochs: 100%|██████████| 10/10 [00:20<00:00,  2.07s/it]
# LightFM training batches:  83%|████████▎ | 58/70 [19:43<04:03, 20.27s/it]
# LightFM batch 59 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 59 epochs:  10%|█         | 1/10 [00:01<00:15,  1.68s/it]
# LightFM batch 59 epochs:  20%|██        | 2/10 [00:03<00:13,  1.74s/it]
# LightFM batch 59 epochs:  30%|███       | 3/10 [00:05<00:12,  1.75s/it]
# LightFM batch 59 epochs:  40%|████      | 4/10 [00:06<00:10,  1.76s/it]
# LightFM batch 59 epochs:  50%|█████     | 5/10 [00:09<00:10,  2.05s/it]
# LightFM batch 59 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.98s/it]
# LightFM batch 59 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.92s/it]
# LightFM batch 59 epochs:  80%|████████  | 8/10 [00:14<00:03,  1.88s/it]
# LightFM batch 59 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.86s/it]
# LightFM batch 59 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.85s/it]
# LightFM training batches:  84%|████████▍ | 59/70 [20:02<03:39, 19.96s/it]
# LightFM batch 60 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 60 epochs:  10%|█         | 1/10 [00:02<00:23,  2.58s/it]
# LightFM batch 60 epochs:  20%|██        | 2/10 [00:04<00:17,  2.16s/it]
# LightFM batch 60 epochs:  30%|███       | 3/10 [00:06<00:14,  2.03s/it]
# LightFM batch 60 epochs:  40%|████      | 4/10 [00:08<00:11,  1.98s/it]
# LightFM batch 60 epochs:  50%|█████     | 5/10 [00:10<00:09,  1.96s/it]
# LightFM batch 60 epochs:  60%|██████    | 6/10 [00:12<00:07,  1.95s/it]
# LightFM batch 60 epochs:  70%|███████   | 7/10 [00:14<00:06,  2.20s/it]
# LightFM batch 60 epochs:  80%|████████  | 8/10 [00:16<00:04,  2.11s/it]
# LightFM batch 60 epochs:  90%|█████████ | 9/10 [00:18<00:02,  2.05s/it]
# LightFM batch 60 epochs: 100%|██████████| 10/10 [00:20<00:00,  2.02s/it]
# LightFM training batches:  86%|████████▌ | 60/70 [20:23<03:23, 20.33s/it]
# LightFM batch 61 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 61 epochs:  10%|█         | 1/10 [00:01<00:15,  1.75s/it]
# LightFM batch 61 epochs:  20%|██        | 2/10 [00:03<00:15,  1.94s/it]
# LightFM batch 61 epochs:  30%|███       | 3/10 [00:06<00:14,  2.14s/it]
# LightFM batch 61 epochs:  40%|████      | 4/10 [00:08<00:12,  2.03s/it]
# LightFM batch 61 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.97s/it]
# LightFM batch 61 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.94s/it]
# LightFM batch 61 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.92s/it]
# LightFM batch 61 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.97s/it]
# LightFM batch 61 epochs:  90%|█████████ | 9/10 [00:18<00:02,  2.13s/it]
# LightFM batch 61 epochs: 100%|██████████| 10/10 [00:20<00:00,  2.06s/it]
# LightFM training batches:  87%|████████▋ | 61/70 [20:44<03:04, 20.46s/it]
# LightFM batch 62 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 62 epochs:  10%|█         | 1/10 [00:01<00:15,  1.69s/it]
# LightFM batch 62 epochs:  20%|██        | 2/10 [00:03<00:13,  1.74s/it]
# LightFM batch 62 epochs:  30%|███       | 3/10 [00:05<00:12,  1.77s/it]
# LightFM batch 62 epochs:  40%|████      | 4/10 [00:07<00:11,  1.90s/it]
# LightFM batch 62 epochs:  50%|█████     | 5/10 [00:09<00:10,  2.05s/it]
# LightFM batch 62 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.97s/it]
# LightFM batch 62 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.92s/it]
# LightFM batch 62 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.88s/it]
# LightFM batch 62 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.86s/it]
# LightFM batch 62 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.86s/it]
# LightFM training batches:  89%|████████▊ | 62/70 [21:03<02:41, 20.14s/it]
# LightFM batch 63 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 63 epochs:  10%|█         | 1/10 [00:02<00:18,  2.11s/it]
# LightFM batch 63 epochs:  20%|██        | 2/10 [00:03<00:14,  1.87s/it]
# LightFM batch 63 epochs:  30%|███       | 3/10 [00:05<00:12,  1.81s/it]
# LightFM batch 63 epochs:  40%|████      | 4/10 [00:07<00:10,  1.79s/it]
# LightFM batch 63 epochs:  50%|█████     | 5/10 [00:09<00:08,  1.77s/it]
# LightFM batch 63 epochs:  60%|██████    | 6/10 [00:10<00:07,  1.77s/it]
# LightFM batch 63 epochs:  70%|███████   | 7/10 [00:13<00:06,  2.02s/it]
# LightFM batch 63 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.94s/it]
# LightFM batch 63 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.89s/it]
# LightFM batch 63 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.85s/it]
# LightFM training batches:  90%|█████████ | 63/70 [21:23<02:19, 19.99s/it]
# LightFM batch 64 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 64 epochs:  10%|█         | 1/10 [00:01<00:16,  1.83s/it]
# LightFM batch 64 epochs:  20%|██        | 2/10 [00:03<00:14,  1.86s/it]
# LightFM batch 64 epochs:  30%|███       | 3/10 [00:06<00:15,  2.23s/it]
# LightFM batch 64 epochs:  40%|████      | 4/10 [00:08<00:12,  2.11s/it]
# LightFM batch 64 epochs:  50%|█████     | 5/10 [00:10<00:10,  2.05s/it]
# LightFM batch 64 epochs:  60%|██████    | 6/10 [00:12<00:08,  2.01s/it]
# LightFM batch 64 epochs:  70%|███████   | 7/10 [00:14<00:05,  1.98s/it]
# LightFM batch 64 epochs:  80%|████████  | 8/10 [00:16<00:03,  1.97s/it]
# LightFM batch 64 epochs:  90%|█████████ | 9/10 [00:18<00:02,  2.20s/it]
# LightFM batch 64 epochs: 100%|██████████| 10/10 [00:20<00:00,  2.13s/it]
# LightFM training batches:  91%|█████████▏| 64/70 [21:44<02:02, 20.40s/it]
# LightFM batch 65 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 65 epochs:  10%|█         | 1/10 [00:01<00:15,  1.70s/it]
# LightFM batch 65 epochs:  20%|██        | 2/10 [00:03<00:14,  1.76s/it]
# LightFM batch 65 epochs:  30%|███       | 3/10 [00:05<00:12,  1.79s/it]
# LightFM batch 65 epochs:  40%|████      | 4/10 [00:07<00:11,  1.86s/it]
# LightFM batch 65 epochs:  50%|█████     | 5/10 [00:09<00:10,  2.08s/it]
# LightFM batch 65 epochs:  60%|██████    | 6/10 [00:11<00:07,  2.00s/it]
# LightFM batch 65 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.95s/it]
# LightFM batch 65 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.92s/it]
# LightFM batch 65 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.90s/it]
# LightFM batch 65 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.91s/it]
# LightFM training batches:  93%|█████████▎| 65/70 [22:04<01:40, 20.19s/it]
# LightFM batch 66 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 66 epochs:  10%|█         | 1/10 [00:02<00:19,  2.12s/it]
# LightFM batch 66 epochs:  20%|██        | 2/10 [00:03<00:15,  1.91s/it]
# LightFM batch 66 epochs:  30%|███       | 3/10 [00:05<00:12,  1.85s/it]
# LightFM batch 66 epochs:  40%|████      | 4/10 [00:07<00:11,  1.84s/it]
# LightFM batch 66 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.83s/it]
# LightFM batch 66 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.84s/it]
# LightFM batch 66 epochs:  70%|███████   | 7/10 [00:13<00:06,  2.09s/it]
# LightFM batch 66 epochs:  80%|████████  | 8/10 [00:15<00:04,  2.01s/it]
# LightFM batch 66 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.95s/it]
# LightFM batch 66 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.92s/it]
# LightFM training batches:  94%|█████████▍| 66/70 [22:24<01:20, 20.21s/it]
# LightFM batch 67 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 67 epochs:  10%|█         | 1/10 [00:01<00:15,  1.69s/it]
# LightFM batch 67 epochs:  20%|██        | 2/10 [00:03<00:13,  1.74s/it]
# LightFM batch 67 epochs:  30%|███       | 3/10 [00:05<00:14,  2.10s/it]
# LightFM batch 67 epochs:  40%|████      | 4/10 [00:07<00:11,  1.98s/it]
# LightFM batch 67 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.92s/it]
# LightFM batch 67 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.89s/it]
# LightFM batch 67 epochs:  70%|███████   | 7/10 [00:13<00:05,  1.87s/it]
# LightFM batch 67 epochs:  80%|████████  | 8/10 [00:15<00:03,  1.86s/it]
# LightFM batch 67 epochs:  90%|█████████ | 9/10 [00:17<00:02,  2.09s/it]
# LightFM batch 67 epochs: 100%|██████████| 10/10 [00:19<00:00,  2.01s/it]
# LightFM training batches:  96%|█████████▌| 67/70 [22:45<01:00, 20.20s/it]
# LightFM batch 68 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 68 epochs:  10%|█         | 1/10 [00:01<00:16,  1.78s/it]
# LightFM batch 68 epochs:  20%|██        | 2/10 [00:03<00:14,  1.85s/it]
# LightFM batch 68 epochs:  30%|███       | 3/10 [00:05<00:13,  1.87s/it]
# LightFM batch 68 epochs:  40%|████      | 4/10 [00:07<00:11,  1.90s/it]
# LightFM batch 68 epochs:  50%|█████     | 5/10 [00:10<00:10,  2.17s/it]
# LightFM batch 68 epochs:  60%|██████    | 6/10 [00:12<00:08,  2.08s/it]
# LightFM batch 68 epochs:  70%|███████   | 7/10 [00:14<00:06,  2.03s/it]
# LightFM batch 68 epochs:  80%|████████  | 8/10 [00:15<00:03,  2.00s/it]
# LightFM batch 68 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.98s/it]
# LightFM batch 68 epochs: 100%|██████████| 10/10 [00:19<00:00,  2.02s/it]
# LightFM training batches:  97%|█████████▋| 68/70 [23:05<00:40, 20.33s/it]
# LightFM batch 69 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 69 epochs:  10%|█         | 1/10 [00:01<00:17,  1.99s/it]
# LightFM batch 69 epochs:  20%|██        | 2/10 [00:03<00:14,  1.87s/it]
# LightFM batch 69 epochs:  30%|███       | 3/10 [00:05<00:12,  1.85s/it]
# LightFM batch 69 epochs:  40%|████      | 4/10 [00:07<00:11,  1.84s/it]
# LightFM batch 69 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.84s/it]
# LightFM batch 69 epochs:  60%|██████    | 6/10 [00:11<00:07,  1.92s/it]
# LightFM batch 69 epochs:  70%|███████   | 7/10 [00:13<00:06,  2.08s/it]
# LightFM batch 69 epochs:  80%|████████  | 8/10 [00:15<00:04,  2.00s/it]
# LightFM batch 69 epochs:  90%|█████████ | 9/10 [00:17<00:01,  1.96s/it]
# LightFM batch 69 epochs: 100%|██████████| 10/10 [00:19<00:00,  1.93s/it]
# LightFM training batches:  99%|█████████▊| 69/70 [23:26<00:20, 20.34s/it]
# LightFM batch 70 epochs:   0%|          | 0/10 [00:00<?, ?it/s]
# LightFM batch 70 epochs:  10%|█         | 1/10 [00:01<00:14,  1.60s/it]
# LightFM batch 70 epochs:  20%|██        | 2/10 [00:03<00:14,  1.76s/it]
# LightFM batch 70 epochs:  30%|███       | 3/10 [00:05<00:13,  1.99s/it]
# LightFM batch 70 epochs:  40%|████      | 4/10 [00:07<00:11,  1.89s/it]
# LightFM batch 70 epochs:  50%|█████     | 5/10 [00:09<00:09,  1.83s/it]
# LightFM batch 70 epochs:  60%|██████    | 6/10 [00:10<00:07,  1.80s/it]
# LightFM batch 70 epochs:  70%|███████   | 7/10 [00:12<00:05,  1.77s/it]
# LightFM batch 70 epochs:  80%|████████  | 8/10 [00:14<00:03,  1.77s/it]
# LightFM batch 70 epochs:  90%|█████████ | 9/10 [00:16<00:01,  1.96s/it]
# LightFM batch 70 epochs: 100%|██████████| 10/10 [00:18<00:00,  1.94s/it]
# LightFM training batches: 100%|██████████| 70/70 [23:45<00:00, 20.36s/it]

# %% [markdown]
# ## Ансамбль

# %%
import pickle
from tqdm import tqdm
from scipy.sparse import csr_matrix

# Select 10% of users from test
test_subset = test.sample(fraction=0.1, seed=42)
test_subset_users = test_subset["user_id"].to_list()

# Filter test_exploded for these users
test_exploded_subset = test_exploded.filter(pl.col("user_id").is_in(test_subset_users))

print("Original test size:", test.shape[0])
print("Test subset size:", test_subset.shape[0])
print("Test exploded subset size:", test_exploded_subset.shape[0])

# Load models
try:
    popular_model = pickle.load(open("popular_model.pkl", "rb"))
    knn_model = pickle.load(open("knn_model.pkl", "rb"))
    lfm_model = pickle.load(open("lfm_model.pkl", "rb"))
except FileNotFoundError as e:
    print(f"Error: Model file not found - {e}")
    raise

# Check structure of popular_model
print("Type of popular_model:", type(popular_model))
if isinstance(popular_model, dict) and "popular_items" in popular_model:
    popular_items = popular_model["popular_items"]
elif isinstance(popular_model, list):
    popular_items = popular_model  # Assume it's the list of popular items
else:
    raise ValueError("Unexpected structure for popular_model. Expected dict with 'popular_items' or list.")

# Create sparse matrix for ItemKNN (if not already defined)
user_ids = train["user_id"].unique().to_list()
item_ids = train["item_id"].unique().to_list()
user_map = {uid: i for i, uid in enumerate(user_ids)}
item_map = {iid: i for i, iid in enumerate(item_ids)}
data = (train["rating"].to_numpy() + 1).astype(np.float64)
row = train["user_id"].replace(user_map).to_numpy().astype(np.int32)
col = train["item_id"].replace(item_map).to_numpy().astype(np.int32)
sparse = csr_matrix((data, (row, col)), shape=(len(user_ids), len(item_ids)))

# Popular predictions
recs_popular = [popular_items[:10] for _ in range(test_subset.shape[0])]
test_subset = test_subset.with_columns(pl.Series("popular_recs", recs_popular))

# ItemKNN predictions
recs_knn = []
for uid in tqdm(test_subset["user_id"], desc="ItemKNN predictions (subset)"):
    u_idx = knn_model["user_map"].get(uid, -1)
    if u_idx == -1:
        recs_knn.append(popular_items[:10])
    else:
        recs, _ = knn_model["model"].recommend(u_idx, sparse[u_idx], N=10, filter_already_liked_items=True)
        recs_knn.append([knn_model["item_ids"][r] for r in recs if r < len(knn_model["item_ids"])] or popular_items[:10])
test_subset = test_subset.with_columns(pl.Series("knn_recs", recs_knn))

# LightFM predictions
recs_lfm = []
user_mapping, _, item_mapping, _ = lfm_model["dataset"].mapping()
for uid in tqdm(test_subset["user_id"], desc="LightFM predictions (subset)"):
    u_idx = user_mapping.get(uid)
    if u_idx is None:
        recs_lfm.append(popular_items[:10])
    else:
        scores = lfm_model["model"].predict(u_idx, np.arange(len(lfm_model["all_items"])))
        top = np.argsort(-scores)[:10]
        recs_lfm.append([lfm_model["all_items"][top_i] for top_i in top])
test_subset = test_subset.with_columns(pl.Series("lfm_recs", recs_lfm))
# Out:
# Original test size: 185828
# Test subset size: 18582
# Test exploded subset size: 305880
# Type of popular_model: <class 'list'>
# ItemKNN predictions (subset): 100%|██████████| 18582/18582 [00:01<00:00, 11378.04it/s]
# LightFM predictions (subset): 100%|██████████| 18582/18582 [08:17<00:00, 37.38it/s]

# %%
# Simple ensemble (union)
recs_ensemble = []
for i, row in enumerate(test_subset.iter_rows(named=True)):
    pop = row["popular_recs"]
    knn = row["knn_recs"]
    lfm = row["lfm_recs"]
    ensemble = list(set(pop + knn + lfm))[:10]
    recs_ensemble.append(ensemble)
test_subset = test_subset.with_columns(pl.Series("ensemble_recs", recs_ensemble))

# Weighted ensemble
recs_ensemble_weighted = []
for i, row in enumerate(test_subset.iter_rows(named=True)):
    pop = row["popular_recs"]
    knn = row["knn_recs"]
    lfm = row["lfm_recs"]
    scores = {}
    for j, item in enumerate(pop):
        scores[item] = scores.get(item, 0) + 0.2 * (10 - j)
    for j, item in enumerate(knn):
        scores[item] = scores.get(item, 0) + 0.3 * (10 - j)
    for j, item in enumerate(lfm):
        scores[item] = scores.get(item, 0) + 0.5 * (10 - j)
    ensemble = sorted(scores, key=scores.get, reverse=True)[:10]
    recs_ensemble_weighted.append(ensemble)
test_subset = test_subset.with_columns(pl.Series("ensemble_weighted_recs", recs_ensemble_weighted))

# %% [markdown]
# ## Оценка

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Проверяем структуру test_subset
print("Columns in test_subset before metrics:", test_subset.columns)
if "user_id" not in test_subset.columns:
    raise ValueError("test_subset не содержит колонку 'user_id'. Проверьте предыдущие операции.")
if not any(col in test_subset.columns for col in ["popular_recs", "knn_recs", "lfm_recs", "ensemble_recs", "ensemble_weighted_recs"]):
    print("Ошибка: Ни одна колонка рекомендаций не найдена в test_subset. Доступные колонки:", test_subset.columns)
    print("Проверьте блоки предсказаний и ансамбля (Блоки 2 и 3). Убедитесь, что with_columns добавляет колонки 'popular_recs', 'knn_recs', 'lfm_recs', 'ensemble_recs', 'ensemble_weighted_recs'.")
    raise ValueError("Не удалось вычислить метрики: отсутствуют колонки рекомендаций в test_subset.")

# Проверяем наличие test_exploded_subset для ColdRecall@10
if 'test_exploded_subset' not in globals():
    print("Ошибка: test_exploded_subset не определён. Проверьте блок выборки 10% датасета (Блок 1).")
    raise ValueError("test_exploded_subset необходим для вычисления ColdRecall@10.")

# Предполагаем, что total_items определён
total_items = books["item_id"].n_unique()

# Вычисляем метрики
metrics_list = []
for col in ["popular_recs", "knn_recs", "lfm_recs", "ensemble_recs", "ensemble_weighted_recs"]:
    if col not in test_subset.columns:
        print(f"Предупреждение: Колонка {col} не найдена в test_subset. Пропускаем.")
        continue
    try:
        recs_df = test_subset.select("user_id", pl.col(col).alias("recs"))
        metrics = evaluate_model(recs_df, test_subset, col.split("_")[0], total_items)
        metrics_list.append(metrics)
    except Exception as e:
        print(f"Ошибка при вычислении метрик для {col}: {str(e)}")

if not metrics_list:
    print("Ошибка: Не удалось вычислить ни одну метрику. Проверьте, добавлены ли колонки рекомендаций в test_subset.")
    print("Рекомендация: Проверьте логи предсказаний (Блок 2) и ансамбля (Блок 3): длины списков recs_popular, recs_knn, recs_lfm и их содержимое.")
    raise ValueError("Не удалось вычислить метрики: ни одна колонка рекомендаций не обработана.")

metrics_df = pd.DataFrame(metrics_list)
display(metrics_df)

# Визуализация
if not metrics_df.empty:
    plt.figure(figsize=(10, 6))
    metrics_df.set_index("Model")[["Recall@10", "NDCG@10", "Coverage", "ColdRecall@10"]].plot(kind="bar")
    plt.title("Metrics Comparison on 10% Test Subset")
    plt.xlabel("Model")
    plt.ylabel("Metric Value")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print("Визуализация не выполнена: metrics_df пуст.")
